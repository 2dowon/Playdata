# %% [markdown]
# ### 네이버 뮤직 1위~100위까지 추출하기

# %%
import requests
from bs4 import BeautifulSoup
import glob
    
naver_music_url = "http://music.naver.com/listen/history/index.nhn?type=DOMESTIC&year=2017&month=12&week=1&page="
 
# 네이버 music 주소를 입력하면 노래 제목과 아티스트를 반환
def naver_music(url):    
    html_music = requests.get(url).text
    soup_music = BeautifulSoup(html_music, "lxml")

    titles = soup_music.select('a._title span.ellipsis') 
    artists = soup_music.select('td._artist a')

    music_titles = [title.get_text() for title in titles]
    music_artists = [artist.get_text().strip() for artist in artists]
    
    return music_titles, music_artists

# 각 page에는 50개의 노래 제목과 아티스트가 추출됨
for page in range(2):
    naver_music_url_page = naver_music_url + str(page+1) # page URL
    naver_music_titles, naver_music_artists = naver_music(naver_music_url_page)
    
    # 추출된 노래 제목과 아티스트를 파일에 저장 
    for k in range(len(naver_music_titles)):
        #print("{0:2d}: {1}/{2}\n".format(page*50 + k+1, naver_music_titles[k],  naver_music_artists[k]))
        print(f"{page*50 + k+1}위 : {naver_music_titles[k]}/{naver_music_artists[k]}\n")
# Out:
# 1위 : 눈 (Feat. 이문세)/Zion.T
#
# 2위 : 기억의 빈자리/나얼
#
# 3위 : 선물/멜로망스(Melomance)
#
# 4위 : Beautiful/Wanna One(워너원)
#
# 5위 : 좋아/민서
#
# 6위 : 피카부 (Peek-A-Boo)/Red Velvet (레드벨벳)
#
# 7위 : 좋니/윤종신
#
# 8위 : WHERE YOU AT/뉴이스트 W
#
# 9위 : LIKEY/TWICE(트와이스)
#
# 10위 : 그때의 나, 그때의 우리/어반자카파
#
# 11위 : 있다면/뉴이스트 W
#
# 12위 : 뻔한 이별 (PROD. 13)/소유 (SOYOU..
#
# 13위 : 하루만/뉴이스트 W
#
# 14위 : 여보세요/뉴이스트
#
# 15위 : DNA/방탄소년단
#
# 16위 : 갖고 싶어/Wanna One(워너원)
#
# 17위 : 에너제틱 (Energetic)/Wanna One(워너원)
#
# 18위 : 특별해/젝스키스
#
# 19위 : 연애소설 (Feat. 아이유)/에픽하이 (EPIK HIGH)
#
# 20위 : 썸 탈꺼야/볼빨간사춘기
#
# 21위 : 웃어줘/젝스키스
#
# 22위 : 지금까지 행복했어요 (BAEKHO SOLO)/뉴이스트 W
#
# 23위 : 그리워하다/비투비
#
# 24위 : GOOD LOVE (ARON SOLO)/뉴이스트 W
#
# 25위 : Twilight/Wanna One(워너원)
#
# 26위 : 밤편지/아이유(IU)
#
# 27위 : PARADISE (REN SOLO)/뉴이스트 W
#
# 28위 : WITH (JR SOLO)/뉴이스트 W
#
# 29위 : 봄날/방탄소년단
#
# 30위 : Nothing Without You (Intro.)/Wanna One(워너원)
#
# 31위 : 아프지 마요/젝스키스
#
# 32위 : 시차 (We Are) (Feat. 로꼬 & GRAY)/우원재
#
# 33위 : 오랜만이에요/젝스키스
#
# 34위 : 백허그/젝스키스
#
# 35위 : MOVE/태민(TAEMIN)
#
# 36위 : 슬픈 노래/젝스키스
#
# 37위 : 나의 사춘기에게/볼빨간사춘기
#
# 38위 : 네가 필요해/젝스키스
#
# 39위 : 술끊자/젝스키스
#
# 40위 : 다신/젝스키스
#
# 41위 : REALLY REALLY/WINNER
#
# 42위 : 느낌이 와/젝스키스
#
# 43위 : 첫눈처럼 너에게 가겠다/에일리(AILEE)
#
# 44위 : 현기증/젝스키스
#
# 45위 : 나의 밤 나의 너/성시경
#
# 46위 : 세 단어/젝스키스
#
# 47위 : 비도 오고 그래서 (Feat. 신용재)/헤이즈(Heize)
#
# 48위 : 빈차 (Feat. 오혁)/에픽하이 (EPIK HIGH)
#
# 49위 : MIC Drop (Steve Aoki Remix) (Feat. Desiigner)/방탄소년단
#
# 50위 : 가을 아침/아이유(IU)
#
# 51위 : 가시나/선미
#
# 52위 : all of my life/박원
#
# 53위 : To Be One (Outro.)/Wanna One(워너원)
#
# 54위 : 비행운/문문(MoonMoon)
#
# 55위 : 고민보다 Go/방탄소년단
#
# 56위 : 빨간 맛 (Red Flavor)/Red Velvet (레드벨벳)
#
# 57위 : 덜덜덜/EXID
#
# 58위 : 밤이 되니까/펀치 (Punch)
#
# 59위 : 피 땀 눈물/방탄소년단
#
# 60위 : Blue/볼빨간사춘기
#
# 61위 : MIC Drop/방탄소년단
#
# 62위 : Ko Ko Bop/EXO
#
# 63위 : 매일 듣는 노래 (A Daily Song)/황치열
#
# 64위 : 그 사람을 아나요/임창정
#
# 65위 : LOVE ME LOVE ME/WINNER
#
# 66위 : Lip ＆ Hip/현아
#
# 67위 : 얼굴 찌푸리지 말아요/하이라이트(Highlight)
#
# 68위 : 어쩔 수 없지 뭐/하이라이트(Highlight)
#
# 69위 : Power/EXO
#
# 70위 : ISLAND/WINNER
#
# 71위 : 종소리/러블리즈
#
# 72위 : Best Of Me/방탄소년단
#
# 73위 : 마지막처럼/BLACKPINK
#
# 74위 : 남이 될 수 있을까/볼빨간사춘기
#
# 75위 : 박수/세븐틴
#
# 76위 : 성냥팔이 소녀 (The Little Match Girl)/백아연
#
# 77위 : 안 될 사랑/한동근
#
# 78위 : 잠 못 드는 밤 비는 내리고/아이유(IU)
#
# 79위 : 팔레트 (Feat. G-DRAGON)/아이유(IU)
#
# 80위 : 노땡큐 (Feat. MINO, 사이먼 도미닉, 더콰이엇)/에픽하이 (EPIK HIGH)
#
# 81위 : 첫사랑 (Feat. 유주 Of 여자친구)/정키(JungKey)
#
# 82위 : 비밀의 화원/아이유(IU)
#
# 83위 : Thirsty (OFF-SICK Concert Ver.)/태민(TAEMIN)
#
# 84위 : 활활 (Burn It Up)/Wanna One(워너원)
#
# 85위 : Beautiful/크러쉬(CRUSH)
#
# 86위 : 노력/박원
#
# 87위 : Wanna Be (My Baby)/Wanna One(워너원)
#
# 88위 : 처음부터 너와 나/볼빨간사춘기
#
# 89위 : 에너제틱 (Energetic) (Prequel Remix)/Wanna One(워너원)
#
# 90위 : CALLING YOU/하이라이트(Highlight)
#
# 91위 : 무제(無題) (Untitled, 2014)/G-DRAGON
#
# 92위 : CELEBRATE/하이라이트(Highlight)
#
# 93위 : 같은 시간 속의 너/나얼
#
# 94위 : 활활 (Burn It Up) (Prequel Remix)/Wanna One(워너원)
#
# 95위 : 바람의 노래/소향
#
# 96위 : WHO AM I/하이라이트(Highlight)
#
# 97위 : 캔디 (Candy)/사무엘
#
# 98위 : 전야 (前夜) (The Eve)/EXO
#
# 99위 : TAKE ON ME/하이라이트(Highlight)
#
# 100위 : 러브스토리 (Feat. 크러쉬)/SURAN(수란)

# %% [markdown]
# ### 추출한 네이버뮤직 TOP100을 엑셀파일에 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["순위", "노래 제목", "아티스트"])

naver_music_url = "http://music.naver.com/listen/history/index.nhn?type=DOMESTIC&year=2017&month=12&week=1&page="

# 네이버 music 주소를 입력하면 노래 제목과 아티스트를 반환
def naver_music(url):    
    html_music = requests.get(url).text
    soup_music = BeautifulSoup(html_music, "lxml")

    titles = soup_music.select('a._title span.ellipsis') 
    artists = soup_music.select('td._artist a')

    music_titles = [title.get_text() for title in titles]
    music_artists = [artist.get_text().strip() for artist in artists]
    
    return music_titles, music_artists

# 각 page에는 50개의 노래 제목과 아티스트가 추출됨
for page in range(2):
    naver_music_url_page = naver_music_url + str(page+1) # page URL
    naver_music_titles, naver_music_artists = naver_music(naver_music_url_page)
    
    for k in range(len(naver_music_titles)):
        sheet.append([page*50 + k+1,naver_music_titles[k], naver_music_artists[k]])
    
wb.save("NaverMusicTop100.xlsx")

# %% [markdown]
# ### input으로 받아서 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["순위", "노래 제목", "아티스트"])

year = input("검색하고 싶은 년도를 입력하세요 :")
month = input("검색하고 싶은 월을 입력하세요 :")
week = input("검색하고 싶은 주를 입력하세요 :")

if len(month) == 1:
    month = "0" + month
else:
    month = month
    
naver_music_url = f"https://music.naver.com/listen/history/index.nhn?type=TOTAL_V2&year={year}&month={month}&week={week}&page="

# 네이버 music 주소를 입력하면 노래 제목과 아티스트를 반환
def naver_music(url):    
    html_music = requests.get(url).text
    soup_music = BeautifulSoup(html_music, "lxml")

    titles = soup_music.select('a._title span.ellipsis') 
    artists = soup_music.select('td._artist a')

    music_titles = [title.get_text() for title in titles]
    music_artists = [artist.get_text().strip() for artist in artists]
    
    return music_titles, music_artists

# 각 page에는 50개의 노래 제목과 아티스트가 추출됨
for page in range(2):
    naver_music_url_page = naver_music_url + str(page+1) # page URL
    naver_music_titles, naver_music_artists = naver_music(naver_music_url_page)
    
    for k in range(len(naver_music_titles)):
        sheet.append([page*50 + k+1,naver_music_titles[k], naver_music_artists[k]])
    
wb.save(f"NaverMusicTop100 {year}년 {month}월 {week}주.xlsx")
# Out:
# 검색하고 싶은 년도를 입력하세요 :2020
# 검색하고 싶은 월을 입력하세요 :1
# 검색하고 싶은 주를 입력하세요 :1

# %% [markdown]
# ### sheet 추가하기

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl

year = input("검색하고 싶은 년도를 입력하세요 :")
month = input("검색하고 싶은 월을 입력하세요 :")
week = input("검색하고 싶은 주를 입력하세요 :")

if len(month) == 1:
    month = "0" + month
else:
    month = month
    
naver_music_url = f"https://music.naver.com/listen/history/index.nhn?type=TOTAL_V2&year={year}&month={month}&week={week}&page="

wb = openpyxl.Workbook()
sheet = wb.active
sheet.title = f"{year}년 {month}주 {week}주"
sheet.append(["순위", "노래 제목", "아티스트"])

# 네이버 music 주소를 입력하면 노래 제목과 아티스트를 반환
def naver_music(url):    
    html_music = requests.get(url).text
    soup_music = BeautifulSoup(html_music, "lxml")

    titles = soup_music.select('a._title span.ellipsis') 
    artists = soup_music.select('td._artist a')

    music_titles = [title.get_text() for title in titles]
    music_artists = [artist.get_text().strip() for artist in artists]
    
    return music_titles, music_artists

# 각 page에는 50개의 노래 제목과 아티스트가 추출됨
for page in range(2):
    naver_music_url_page = naver_music_url + str(page+1) # page URL
    naver_music_titles, naver_music_artists = naver_music(naver_music_url_page)
    
    for k in range(len(naver_music_titles)):
        sheet.append([page*50 + k+1,naver_music_titles[k], naver_music_artists[k]])
    
wb.save(f"NaverMusicTop100 {year}년 {month}월 {week}주.xlsx")
# Out:
# 검색하고 싶은 년도를 입력하세요 :2020
# 검색하고 싶은 월을 입력하세요 :4
# 검색하고 싶은 주를 입력하세요 :4
