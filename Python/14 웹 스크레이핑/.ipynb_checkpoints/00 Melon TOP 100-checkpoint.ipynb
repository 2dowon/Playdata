# %% [markdown]
# ### 크롤링이 안될 때 (서버에서 막아서)

# %%
import requests

url = "https://www.melon.com/new/index.htm#params%5BareaFlg%5D=I&po=pageObj&startIndex=1"    

html_music = requests.get(url)
html_music
# Out:
# <Response [406]>

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
url ='https://www.melon.com/new/index.htm#params%5BareaFlg%5D=I&po=pageObj&startIndex=1'
html = requests.get(url, headers = headers).text

# %% [markdown]
# ### 1위부터 7위까지 추출

# %% [markdown]
# #### 노래 1곡에 아티스트가 2명인 경우, 아티스트가 한 명씩 뒤로 밀리는 문제 발생

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

url = "https://www.melon.com/new/index.htm#params%5BareaFlg%5D=I&po=pageObj&startIndex=1"    

html_music = requests.get(url, headers = headers).text
soup_music = BeautifulSoup(html_music, "lxml")

titles = soup_music.select("div.rank01 span a") 
artists = soup_music.select('div.rank02 span a')

music_titles = [title.get_text() for title in titles]
music_artists = [artist.get_text().strip() for artist in artists]

for k in range(7):
    print("{0}: {1} / {2}".format(k+1, music_titles[k], music_artists[k]))
# Out:
# 1: Dancing Cartoon / 볼빨간사춘기
# 2: GOTCHA / 박지훈
# 3: Bless You (Feat. 샘김, WOODZ, pH-1) / 프라이머리
# 4: Got That Boom / SECRET NUMBER (시크릿넘버)
# 5: Love or Lies / 보라미유
# 6: 너의 이름을 불러봐 / 박지용 (허니지)
# 7: Listen (feat. Basick) / DJ Wreckx (디제이렉스)

# %% [markdown]
# ### 1위부터 100위까지 추출하기

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}

melon_music_url = "https://www.melon.com/new/index.htm#params%5BareaFlg%5D=I&po=pageObj&startIndex="
 
# 네이버 music 주소를 입력하면 노래 제목과 아티스트를 반환
def melon_music(url):    
    html_music = requests.get(url, headers = headers).text
    soup_music = BeautifulSoup(html_music, "lxml")

    titles = soup_music.select("div.rank01 span a") 
    artists = soup_music.select('div.rank02 span a')

    music_titles = [title.get_text() for title in titles]
    music_artists = [artist.get_text().strip() for artist in artists]
    
    return music_titles, music_artists

# 각 page에는 50개의 노래 제목과 아티스트가 추출됨
for page in range(2):
    melon_music_url_page = melon_music_url + str(page*50+1) # page URL
    melon_music_titles, melon_music_artists = melon_music(melon_music_url_page)
    
    # 추출된 노래 제목과 아티스트를 파일에 저장 
    for k in range(len(melon_music_titles)):
        print(f"{page*50 + k+1}위 : {melon_music_titles[k]}/{melon_music_artists[k]}\n")
# Out:
# 1위 : Dancing Cartoon/볼빨간사춘기
#
# 2위 : GOTCHA/박지훈
#
# 3위 : Bless You (Feat. 샘김, WOODZ, pH-1)/프라이머리
#
# 4위 : Got That Boom/SECRET NUMBER (시크릿넘버)
#
# 5위 : Love or Lies/보라미유
#
# 6위 : 너의 이름을 불러봐/박지용 (허니지)
#
# 7위 : Listen (feat. Basick)/DJ Wreckx (디제이렉스)
#
# 8위 : HERO/임영웅
#
# 9위 : 호랑이는 죽어서 가죽을, 우리는 이름을/홈보이 (Homeboy)
#
# 10위 : 떨어져 (Please Go Away)/에네이 에미 (Enei Emi)
#
# 11위 : 싸이코4U/NIDA
#
# 12위 : AYA/걸카인드 (GIRLKIND)
#
# 13위 : SOON (Feat. BewhY)/마마무 (Mamamoo)
#
# 14위 : Bangkok (Stay Home)/다이나믹 듀오
#
# 15위 : By your side (Feat. E.N.D., SLOC)/뷰티핸섬
#
# 16위 : 어쩌면 오래전부터/TSLW
#
# 17위 : Winter again/캡틴플래닛
#
# 18위 : 얘랑 있을 때 좋다(with 김국헌 of 비오브유)/이은아
#
# 19위 : I'm alone/Yolk
#
# 20위 : Wind, Star (feat. 이상훈 of 훈스 (HOONS))/어쿠스틱 콜라보
#
# 21위 : 백일홍/The Hills (더 힐스)
#
# 22위 : 잔상 (Vocal. 정구영)/릴리노트 (Lilynote)
#
# 23위 : 귀가 (With 타미즈)/조명섭
#
# 24위 : 너라는 하루를 살아/김현수 (F-IV)
#
# 25위 : 그때 생각나?/42kgb
#
# 26위 : i got you/주호
#
# 27위 : On The Radio (With SERO)/베이비블루(BABY BLUE)
#
# 28위 : 서울/Jimmy Brown
#
# 29위 : Love Killa/SUDI
#
# 30위 : SALUTE/임예송
#
# 31위 : 비행기 모드 (Feat. 바끼리, BRADYSTREET)/몬스타엑스
#
# 32위 : 안돼요/AB6IX (에이비식스)
#
# 33위 : G.B.T.B. (Strong Dragon Remix)/나왔구나 김비노
#
# 34위 : OFF/홍진영
#
# 35위 : I need you. Period./VERIVERY
#
# 36위 : 좋아 좋아/새벽두시
#
# 37위 : 강을 향해 간다/Kim Jeong_uk(김정욱)
#
# 38위 : INTRCRSE (Feat. 바끼리)/정다경
#
# 39위 : Fxxkin Insomnia/스마일리스마일 (SmileySmile)
#
# 40위 : 소년/DOPA
#
# 41위 : MOVIE (Feat. Rohann)/MÖA
#
# 42위 : 텅 비었던(ft. 서한)/신지민
#
# 43위 : DIVIN' (Feat. z4vwm (잡음), JUICY KID)/정진우
#
# 44위 : 그대 그리운 날/Xbf
#
# 45위 : Love you Love you (feat.더 브릿지(The Bridge))/온리차일드 (ONLICHILD)
#
# 46위 : Labyrinth/설가령
#
# 47위 : Be bop a lula/브런치 레시피 (Brunch recipe)
#
# 48위 : Lazy Seoul (레이지 서울)/정주 (Jungju)
#
# 49위 : 온도차/얼스 (Earls)
#
# 50위 : 내버려둬(NOYB)/이철호
#
# 51위 : Dancing Cartoon/볼빨간사춘기
#
# 52위 : GOTCHA/박지훈
#
# 53위 : Bless You (Feat. 샘김, WOODZ, pH-1)/프라이머리
#
# 54위 : Got That Boom/SECRET NUMBER (시크릿넘버)
#
# 55위 : Love or Lies/보라미유
#
# 56위 : 너의 이름을 불러봐/박지용 (허니지)
#
# 57위 : Listen (feat. Basick)/DJ Wreckx (디제이렉스)
#
# 58위 : HERO/임영웅
#
# 59위 : 호랑이는 죽어서 가죽을, 우리는 이름을/홈보이 (Homeboy)
#
# 60위 : 떨어져 (Please Go Away)/에네이 에미 (Enei Emi)
#
# 61위 : 싸이코4U/NIDA
#
# 62위 : AYA/걸카인드 (GIRLKIND)
#
# 63위 : SOON (Feat. BewhY)/마마무 (Mamamoo)
#
# 64위 : Bangkok (Stay Home)/다이나믹 듀오
#
# 65위 : By your side (Feat. E.N.D., SLOC)/뷰티핸섬
#
# 66위 : 어쩌면 오래전부터/TSLW
#
# 67위 : Winter again/캡틴플래닛
#
# 68위 : 얘랑 있을 때 좋다(with 김국헌 of 비오브유)/이은아
#
# 69위 : I'm alone/Yolk
#
# 70위 : Wind, Star (feat. 이상훈 of 훈스 (HOONS))/어쿠스틱 콜라보
#
# 71위 : 백일홍/The Hills (더 힐스)
#
# 72위 : 잔상 (Vocal. 정구영)/릴리노트 (Lilynote)
#
# 73위 : 귀가 (With 타미즈)/조명섭
#
# 74위 : 너라는 하루를 살아/김현수 (F-IV)
#
# 75위 : 그때 생각나?/42kgb
#
# 76위 : i got you/주호
#
# 77위 : On The Radio (With SERO)/베이비블루(BABY BLUE)
#
# 78위 : 서울/Jimmy Brown
#
# 79위 : Love Killa/SUDI
#
# 80위 : SALUTE/임예송
#
# 81위 : 비행기 모드 (Feat. 바끼리, BRADYSTREET)/몬스타엑스
#
# 82위 : 안돼요/AB6IX (에이비식스)
#
# 83위 : G.B.T.B. (Strong Dragon Remix)/나왔구나 김비노
#
# 84위 : OFF/홍진영
#
# 85위 : I need you. Period./VERIVERY
#
# 86위 : 좋아 좋아/새벽두시
#
# 87위 : 강을 향해 간다/Kim Jeong_uk(김정욱)
#
# 88위 : INTRCRSE (Feat. 바끼리)/정다경
#
# 89위 : Fxxkin Insomnia/스마일리스마일 (SmileySmile)
#
# 90위 : 소년/DOPA
#
# 91위 : MOVIE (Feat. Rohann)/MÖA
#
# 92위 : 텅 비었던(ft. 서한)/신지민
#
# 93위 : DIVIN' (Feat. z4vwm (잡음), JUICY KID)/정진우
#
# 94위 : 그대 그리운 날/Xbf
#
# 95위 : Love you Love you (feat.더 브릿지(The Bridge))/온리차일드 (ONLICHILD)
#
# 96위 : Labyrinth/설가령
#
# 97위 : Be bop a lula/브런치 레시피 (Brunch recipe)
#
# 98위 : Lazy Seoul (레이지 서울)/정주 (Jungju)
#
# 99위 : 온도차/얼스 (Earls)
#
# 100위 : 내버려둬(NOYB)/이철호

# %% [markdown]
# #### 신지환님 코드

# %%
import openpyxl

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["순위", "제목", "가수","앨범"])
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
url50 = "https://www.melon.com/new/index.htm#params%5BareaFlg%5D=I&po=pageObj&startIndex=51"


raw = requests.get(url50,headers=header).text
html = BeautifulSoup(raw, 'html.parser')
onethree = html.select("div#songList tbody td div div.wrap_song_info")
onethree

i=0
rank = 1
ls = []
for p in onethree:
    i+=1
    song = p.get_text().strip().split("\n")    
    # print(song[0])
    # print(ls)
    
    if i%2==0:
        ls.append(song[0])
        sheet.append(ls)
        print(ls)
        ls.clear()
    else:
        ls.append(rank)
        ls.append(song[0])
#         print(song[3])
        ls.append(song[3][:int(len(song[3])/2)])
        print(ls)
        rank+=1


wb.save("C:/Users/Playdata/Desktop/melon.xlsx")
# Out:
# 챈슬러, 박재범, 이하이, 비비 (BIBI), Jamie (제이미), MOON, 범키, 서사무엘 (Samuel Seo), SURAN (수란), 베이빌론, Hoody (후디), SUMIN (수민), 마샬 (MRSHLL), Ann One, ELO, 트웰브 (twlv), oceanfromtheblue, 지젤 (Jiselle), SOLE (쏠), THAMA, K.vsh (캐시), 진보, 저드 (jerd), 수비 (Soovi), B.E.D. (베드), Xydo (시도), 오웰무드 (Owell Mood), NONE챈슬러, 박재범, 이하이, 비비 (BIBI), Jamie (제이미), MOON, 범키, 서사무엘 (Samuel Seo), SURAN (수란), 베이빌론, Hoody (후디), SUMIN (수민), 마샬 (MRSHLL), Ann One, ELO, 트웰브 (twlv), oceanfromtheblue, 지젤 (Jiselle), SOLE (쏠), THAMA, K.vsh (캐시), 진보, 저드 (jerd), 수비 (Soovi), B.E.D. (베드), Xydo (시도), 오웰무드 (Owell Mood), NONE
# [1, 'AUTOMATIC REMIX', '챈슬러, 박재범, 이하이, 비비 (BIBI), Jamie (제이미), MOON, 범키, 서사무엘 (Samuel Seo), SURAN (수란), 베이빌론, Hoody (후디), SUMIN (수민), 마샬 (MRSHLL), Ann One, ELO, 트웰브 (twlv), oceanfromtheblue, 지젤 (Jiselle), SOLE (쏠), THAMA, K.vsh (캐시), 진보, 저드 (jerd), 수비 (Soovi), B.E.D. (베드), Xydo (시도), 오웰무드 (Owell Mood), NONE']
# 이보람이보람
# [2, '너의 집', '이보람']
# 도파민 (DoPaMine)도파민 (DoPaMine)
# [3, 'Happy Birth Day', '도파민 (DoPaMine)']
# 베리굿 (BerryGood)베리굿 (BerryGood)
# [4, '함께 떠나요 (Accio)', '베리굿 (BerryGood)']
# 차우 (Chawoo)차우 (Chawoo)
# [5, 'HONEY (Feat. 크루셜스타)', '차우 (Chawoo)']
# 볼빨간사춘기볼빨간사춘기
# [6, 'Dancing Cartoon', '볼빨간사춘기']
# 박지훈박지훈
# [7, 'GOTCHA', '박지훈']
# 하림하림
# [8, 'PLAY LIFE', '하림']
# 다혜다혜
# [9, '나쁜 피 (Bad Blood)', '다혜']
# SOUND PALETTESOUND PALETTE
# [10, 'H.A.Y (Song by Lokid) (Feat. PARTI CHILD)', 'SOUND PALETTE']
# iziizi
# [11, '널 좋아했던,널 미워했던 이유', 'izi']
# 하이브로하이브로
# [12, '나만 몰랐어', '하이브로']
# 지윤해지윤해
# [13, '꽃', '지윤해']
# 임인건임인건
# [14, '군산에서', '임인건']
# 림지 (LimJi)림지 (LimJi)
# [15, '어떤색이니', '림지 (LimJi)']
# KODI GREENKODI GREEN
# [16, 'COLDBREW (Prod. SUDI)', 'KODI GREEN']
# SINCESINCE
# [17, '담배피러가자구', 'SINCE']
# 프라이머리프라이머리
# [18, 'Bless You (Feat. 샘김, WOODZ, pH-1)', '프라이머리']
# 킹치메인 (Kingchi Mane), 반고흐킹치메인 (Kingchi Mane), 반고흐
# [19, '개양귀비밭', '킹치메인 (Kingchi Mane), 반고흐']
# 박은옥박은옥
# [20, '찾지 않을게', '박은옥']
# SECRET NUMBER (시크릿넘버)SECRET NUMBER (시크릿넘버)
# [21, 'Got That Boom', 'SECRET NUMBER (시크릿넘버)']
# 보라미유보라미유
# [22, 'Love or Lies', '보라미유']
# 박지용 (허니지)박지용 (허니지)
# [23, '너의 이름을 불러봐', '박지용 (허니지)']
# DJ Wreckx (디제이렉스)DJ Wreckx (디제이렉스)
# [24, 'Listen (feat. Basick)', 'DJ Wreckx (디제이렉스)']
# 임영웅임영웅
# [25, 'HERO', '임영웅']
# 홈보이 (Homeboy), 에네이 에미 (Enei Emi)홈보이 (Homeboy), 에네이 에미 (Enei Emi)
# [26, '호랑이는 죽어서 가죽을, 우리는 이름을', '홈보이 (Homeboy), 에네이 에미 (Enei Emi)']
# NIDANIDA
# [27, '떨어져 (Please Go Away)', 'NIDA']
# 걸카인드 (GIRLKIND)걸카인드 (GIRLKIND)
# [28, '싸이코4U', '걸카인드 (GIRLKIND)']
# 마마무 (Mamamoo)마마무 (Mamamoo)
# [29, 'AYA', '마마무 (Mamamoo)']
# 다이나믹 듀오다이나믹 듀오
# [30, 'SOON (Feat. BewhY)', '다이나믹 듀오']
# 뷰티핸섬뷰티핸섬
# [31, 'Bangkok (Stay Home)', '뷰티핸섬']
# TSLWTSLW
# [32, 'By your side (Feat. E.N.D., SLOC)', 'TSLW']
# 캡틴플래닛, 이은아캡틴플래닛, 이은아
# [33, '어쩌면 오래전부터', '캡틴플래닛, 이은아']
# YolkYolk
# [34, 'Winter again', 'Yolk']
# 어쿠스틱 콜라보어쿠스틱 콜라보
# [35, '얘랑 있을 때 좋다(with 김국헌 of 비오브유)', '어쿠스틱 콜라보']
# The Hills (더 힐스)The Hills (더 힐스)
# [36, "I'm alone", 'The Hills (더 힐스)']
# 릴리노트 (Lilynote)릴리노트 (Lilynote)
# [37, 'Wind, Star (feat. 이상훈 of 훈스 (HOONS))', '릴리노트 (Lilynote)']
# 조명섭조명섭
# [38, '백일홍', '조명섭']
# 김현수 (F-IV)김현수 (F-IV)
# [39, '잔상 (Vocal. 정구영)', '김현수 (F-IV)']
# 42kgb42kgb
# [40, '귀가 (With 타미즈)', '42kgb']
# 주호주호
# [41, '너라는 하루를 살아', '주호']
# 베이비블루(BABY BLUE)베이비블루(BABY BLUE)
# [42, '그때 생각나?', '베이비블루(BABY BLUE)']
# Jimmy BrownJimmy Brown
# [43, 'i got you', 'Jimmy Brown']
# SUDISUDI
# [44, 'On The Radio (With SERO)', 'SUDI']
# 임예송임예송
# [45, '서울', '임예송']
# 몬스타엑스몬스타엑스
# [46, 'Love Killa', '몬스타엑스']
# AB6IX (에이비식스)AB6IX (에이비식스)
# [47, 'SALUTE', 'AB6IX (에이비식스)']
# 나왔구나 김비노나왔구나 김비노
# [48, '비행기 모드 (Feat. 바끼리, BRADYSTREET)', '나왔구나 김비노']
# 홍진영홍진영
# [49, '안돼요', '홍진영']
# VERIVERYVERIVERY
# [50, 'G.B.T.B. (Strong Dragon Remix)', 'VERIVERY']

# %% [markdown]
# ---

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}

url = "https://www.melon.com/chart/index.htm"

raw = requests.get(url,headers=header).text
html = BeautifulSoup(raw, 'html.parser')
onethree = html.select("div#tb_list tbody td div div.wrap_song_info")
onethree

i=0
rank = 1
ls = []
for p in onethree:
    i+=1
    song = p.get_text().strip().split("\n")
    
    if i%2==0:
        ls.append(song[0])
        #sheet.append(ls)
        print(ls)
        ls.clear()
    else:
        ls.append(rank)
        ls.append(song[0])
        ls.append(song[3][:int(len(song[3])/2)])
        rank+=1
# Out:
# [1, 'Dynamite', '', 'Dynamite (DayTime Version)']
# [2, 'Lovesick Girls', '', 'THE ALBUM']
# [3, '힘든 건 사랑이 아니다', '', '힘든 건 사랑이 아니다']
# [4, "DON'T TOUCH ME", '', "DON'T TOUCH ME"]
# [5, '취기를 빌려 (취향저격 그녀 X 산들)', '', '취기를 빌려 (취향저격 그녀 X 산들)']
# [6, '잠이 오질 않네요', '', '잠이 오질 않네요']
# [7, '오래된 노래', '', '오래된 노래']
# [8, 'Savage Love (Laxed - Siren Beat) (BTS Remix)', '', 'Savage Love (Laxed - Siren Beat) [BTS Remix]']
# [9, '내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)', '', '내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)']
# [10, 'When We Disco (Duet with 선미)', '', 'When We Disco']
# [11, '딩가딩가 (Dingga)', '', '딩가딩가 (Dingga)']
# [12, '눈누난나 (NUNU NANA)', '', 'NUNA']
# [13, '놓아줘 (with 태연)', '', 'with HER']
# [14, 'I CAN’T STOP ME', '', 'Eyes wide open']
# [15, '마리아 (Maria)', '', 'María']
# [16, 'How You Like That', '', 'How You Like That']
# [17, '에잇(Prod.&Feat. SUGA of BTS)', '', '에잇']
# [18, '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야', '', '멜로가 체질 OST Part 3']
# [19, 'Dolphin', '', 'NONSTOP']
# [20, '아로하', '', '슬기로운 의사생활 OST Part 3']
# [21, '어떻게 지내 (Prod. By VAN.C)', '', '어떻게 지내']
# [22, 'Dancing Cartoon', '', 'Filmlet']
# [23, '늦은 밤 너의 집 앞 골목길에서', '', '늦은 밤 너의 집 앞 골목길에서']
# [24, '홀로', '', '홀로']
# [25, '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지', '', '항해']
# [26, 'Blueming', '', 'Love poem']
# [27, '다시 여기 바닷가', '', '다시 여기 바닷가']
# [28, 'Downtown Baby', '', 'Downtown Baby']
# [29, 'Dance Monkey', '', 'The Kids Are Coming']
# [30, '거짓말이라도 해서 널 보고싶어', '', '거짓말이라도 해서 널 보고싶어']
# [31, 'METEOR', '', 'Boyhood']
# [32, 'Memories', '', 'Memories']
# [33, '모든 날, 모든 순간 (Every day, Every Moment)', '', '`키스 먼저 할까요?` OST Part.3']
# [34, '사랑은 지날수록 더욱 선명하게 남아', '', '한 걸음 : 흔적']
# [35, '서면역에서', '', '서면역에서']
# [36, '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)', '', 'MAP OF THE SOUL : PERSONA']
# [37, '살짝 설렜어 (Nonstop)', '', 'NONSTOP']
# [38, 'Bad Boy', '', 'Bad Boy']
# [39, '너도 아는', '', '너도 아는']
# [40, '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)', '', 'Red Moon : To You My Light']
# [41, '우리 왜 헤어져야 해', '', '우리 왜 헤어져야 해']
# [42, '2002', '', 'Speak Your Mind (Deluxe)']
# [43, '사랑하게 될 줄 알았어', '', '슬기로운 의사생활 OST Part 11']
# [44, '마음을 드려요', '', '사랑의 불시착 OST Part 11']
# [45, '사랑 못해, 남들 쉽게 다 하는 거', '', '사랑 못해, 남들 쉽게 다 하는 거']
# [46, '처음처럼', '', 'CEREMONIA']
# [47, "Don't Start Now", '', 'Future Nostalgia']
# [48, '나랑 같이 걸을래 (바른연애 길잡이 X 적재)', '', '나랑 같이 걸을래 (바른연애 길잡이 X 적재)']
# [49, 'Ice Cream (with Selena Gomez)', '', 'Ice Cream (with Selena Gomez)']
# [50, '덤디덤디 (DUMDi DUMDi)', '', '덤디덤디 (DUMDi DUMDi)']
# [51, '안녕', '', '호텔 델루나 OST Part.10']
# [52, '봄날', '', 'YOU NEVER WALK ALONE']
# [53, 'AYA', '', 'TRAVEL']
# [54, '너의 곁에만 맴돌아', '', '너의 곁에만 맴돌아']
# [55, 'Pretty Savage', '', 'THE ALBUM']
# [56, 'Not Shy', '', 'Not Shy']
# [57, 'Summer Hate (Feat. 비)', '', 'RANDOM BOX']
# [58, '이제 나만 믿어요', '', '내일은 미스터트롯 우승자 특전곡']
# [59, '아무노래', '', '아무노래']
# [60, '12:45 (Stripped)', '', '12:45 (Stripped)']
# [61, 'Love poem', '', 'Love poem']
# [62, '시작', '', '이태원 클라쓰 OST Part.2']
# [63, '보라빛 밤 (pporappippam)', '', '보라빛 밤 (pporappippam)']
# [64, '가을 타나 봐', '', '가을 타나 봐']
# [65, 'Maniac', '', 'Maniac']
# [66, '행복해', '', 'Happy']
# [67, 'ON', '', 'MAP OF THE SOUL : 7']
# [68, '너를 만나', '', '너를 만나']
# [69, 'Paris In The Rain', '', 'I met you when I was 18. (the playlist)']
# [70, 'HERO', '', 'HERO']
# [71, '별을 담은 시 (Ode To The Stars)', '', 'Red Moon : Ode To The Stars']
# [72, '좋은 사람 있으면 소개시켜줘', '', '슬기로운 의사생활 OST Part 2']
# [73, '잠이 들어야 (Feat. 헤이즈)', '', 'SOME TIME']
# [74, '밤새 (취향저격 그녀 X 카더가든)', '', '밤새 (취향저격 그녀 X 카더가든)']
# [75, '소확행', '', '힘든 건 사랑이 아니다']
# [76, '그때 그 아인', '', '이태원 클라쓰 OST Part.6']
# [77, '취했나봐', '', '취했나봐']
# [78, 'Into the I-LAND', '', 'I-LAND Part.1 Signal Song']
# [79, 'Psycho', '', '‘The ReVe Festival’ Finale']
# [80, '시든 꽃에 물을 주듯', '', '시든 꽃에 물을 주듯']
# [81, '축하해', '', '축하해']
# [82, '도망가', '', 'TAKE']
# [83, 'bad guy', '', 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?']
# [84, '빨간 립스틱', '', 'Filmlet']
# [85, 'Painkiller', '', 'Painkiller']
# [86, '사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))', '', '사랑하고 싶지 않아 (바른연애 길잡이 X XIA (준수))']
# [87, '나비와 고양이 (feat.백현 (BAEKHYUN))', '', '사춘기집Ⅱ 꽃 본 나비']
# [88, '하루도 그대를 사랑하지 않은 적이 없었다', '', '하루도 그대를 사랑하지 않은 적이 없었다']
# [89, '첫 줄', '', 'Dear']
# [90, '사실 나는 (Feat.전건호)', '', '사실 나는']
# [91, 'Stuck with U', '', 'Stuck with U']
# [92, '밤하늘의 저 별처럼', '', '밤하늘의 저 별처럼 (브람스를 좋아하세요? OST 스페셜 트랙)']
# [93, '반만', '', '반만']
# [94, 'ALIEN', '', 'ALIEN']
# [95, '화려하지 않은 고백', '', '슬기로운 의사생활 OST Part 4']
# [96, '사랑이란 멜로는 없어', '', '사랑이란 멜로는 없어']
# [97, '행복하니', '', '추(秋)억']
# [98, '그 여름을 틀어줘', '', '그 여름을 틀어줘']
# [99, 'HIP', '', 'reality in BLACK']
# [100, 'Bless You (Feat. 샘김, WOODZ, pH-1)', '순위', 'Bless You']
