# %%
import requests  
from bs4 import BeautifulSoup 

url = "https://tv.naver.com/r/"

html_tv = requests.get(url).text
soup_tv = BeautifulSoup(html_tv, "lxml")

tv_title = soup_tv.select('dt.title')
tv_title_address = [tv_title_element.text.strip().replace(",", "") for tv_title_element in tv_title]

tv_chn = soup_tv.select('dd.chn')
tv_chn_address = [tv_chn_element.text.strip().replace(",", "") for tv_chn_element in tv_chn]

tv_like = soup_tv.select('span.like')
tv_like_address = [tv_like_element.text.strip().replace(",", "").replace("좋아요 수", "") for tv_like_element in tv_like]

print("[Top 10 in Naver TV]")
for k in range(10):
    print(f"{k+1}위")
    print(f"제목 : {tv_title_address[k+1]}")
    print(f"채널명 : {tv_chn_address[k+1]}")
    print(f"좋아요 수 : {tv_like_address[k+1]}")
    print("\n")
# Out:
# [Top 10 in Naver TV]
# 1위
# 제목 : 잠시만 안녕. 김호중 군복무전 마지막 무대 ＜배웅＞ㅣ김호중의파트너 EP.5
# 채널명 : 아무도 모르게 김호중의 파트너
# 좋아요 수 : 18023
#
#
# 2위
# 제목 : SK감독 선동열 포함 3인 압축 / 김경문 재계약? / 양현종 美가능성 / 최형우 비매너였나
# 채널명 : 야구부장의 크보핵인싸
# 좋아요 수 : 282
#
#
# 3위
# 제목 : 탈락석으로 ‘가지마’♪ 포천의 아들 임영웅 아자!
# 채널명 : 사랑의 콜센타
# 좋아요 수 : 15846
#
#
# 4위
# 제목 : 임영웅 ‘옛사랑’ ♪ 감성 장인 히어로 💧
# 채널명 : 사랑의 콜센타
# 좋아요 수 : 37143
#
#
# 5위
# 제목 : [전체HL] '신민재 끝내기' LG 연장 혈투 끝에 키움 꺾고 준PO 진출
# 채널명 : KBO리그 LG 홈경기 영상
# 좋아요 수 : 1091
#
#
# 6위
# 제목 : ‘금손아내’ 은보아 거침없이 수리해 나가는 만능가이버!
# 채널명 : 동상이몽2_너는 내 운명
# 좋아요 수 : 183
#
#
# 7위
# 제목 : [4회 예고] “죽여버릴거야” 이지아 복수의 서막 시작!
# 채널명 : 펜트하우스
# 좋아요 수 : 293
#
#
# 8위
# 제목 : [선공개] 조리원 열차에 탑승한 꼬리칸 엄마 엄지원X일등칸 엄마 박하선
# 채널명 : 산후조리원
# 좋아요 수 : 118
#
#
# 9위
# 제목 : “후식은 중국집” 김호중×현주엽 끝나지 않는 먹레이스!
# 채널명 : 미운 우리 새끼
# 좋아요 수 : 8988
#
#
# 10위
# 제목 : 나왔다! 찬원이의 필살기↗ ‘미운 사내’ ♬
# 채널명 : 사랑의 콜센타
# 좋아요 수 : 10475

# %% [markdown]
# ### 선생님 코드

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl

wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["제목", "채널명", "좋아요수"])

raw = requests.get("https://tv.naver.com/r/")
html = BeautifulSoup(raw.text, 'lxml')

onethree = html.select("div.inner")

for num1 in onethree:
    title = num1.select_one("dt.title").text.strip().replace(",", "")
    channel = num1.select_one("dd.chn").text.strip().replace(",", "")
    like = num1.select_one("span.like").text.strip().replace(",", "").replace("좋아요 수", "")

    sheet.append([title, channel, like])
    
fourhundred = html.select("div.cds_type")

for num2 in fourhundred:
    title = num2.select_one("dt.title").text.strip().replace(",", "")
    channel = num2.select_one("dd.chn").text.strip().replace(",", "")
    like = num2.select_one("span.like").text.strip().replace(",", "").replace("좋아요 수", "")

    sheet.append([title, channel, like])

wb.save("test.xlsx")

# %%
import requests
from bs4 import BeautifulSoup

raw = requests.get("https://tv.naver.com/r/")
html = BeautifulSoup(raw.text, 'lxml')

html
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <title id="headTitle">
#
#
#
#     		인기영상
#
#     </title>
# <meta charset="utf-8"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="noindex" name="robots"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="100012287952710" property="fb:admins"/>
# <meta content="232491033870086" property="fb:app_id"/>
# <meta content="https://tv.naver.com/r/" property="og:url"/>
# <meta content="Top100 : 네이버TV" property="og:title"/>
# <meta content="동영상을 감상하는 가장 쉽고 빠른 방법" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://ssl.pstatic.net/img.tvcast/common/img/og/180629/OG_Tag_270_270.png" property="og:image"/>
# <link href="/resources/release/css/tvcast_20201030155319.css" rel="stylesheet" type="text/css"/>
# ...
