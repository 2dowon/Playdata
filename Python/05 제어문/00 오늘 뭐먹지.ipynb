# %%
food = ["충무식당", "전주콩나물국밥집", "노브랜드 버거", "송황칼국수", "허수아비 돈까스"]
desert = ["라크레모사",  "루엘드 파리",  "바나프레소", "스타벅스",  "9카페"]

for x in range(len(food)):
    print(food[x], desert[x])
# Out:
# 충무식당 라크레모사
# 전주콩나물국밥집 루엘드 파리
# 노브랜드 버거 바나프레소
# 송황칼국수 스타벅스
# 허수아비 돈까스 9카페

# %%
for x in ["충무식당", "전주콩나물국밥집", "노브랜드 버거", "송황칼국수", "허수아비 돈까스"]:
    for y in ["라크레모사",  "루엘드 파리",  "바나프레소", "스타벅스",  "9카페"]:
        print(x, y)
# Out:
# 충무식당 라크레모사
# 충무식당 루엘드 파리
# 충무식당 바나프레소
# 충무식당 스타벅스
# 충무식당 9카페
# 전주콩나물국밥집 라크레모사
# 전주콩나물국밥집 루엘드 파리
# 전주콩나물국밥집 바나프레소
# 전주콩나물국밥집 스타벅스
# 전주콩나물국밥집 9카페
# 노브랜드 버거 라크레모사
# 노브랜드 버거 루엘드 파리
# 노브랜드 버거 바나프레소
# 노브랜드 버거 스타벅스
# 노브랜드 버거 9카페
# 송황칼국수 라크레모사
# 송황칼국수 루엘드 파리
# 송황칼국수 바나프레소
# 송황칼국수 스타벅스
# 송황칼국수 9카페
# 허수아비 돈까스 라크레모사
# 허수아비 돈까스 루엘드 파리
# 허수아비 돈까스 바나프레소
# 허수아비 돈까스 스타벅스
# 허수아비 돈까스 9카페

# %%
[ (x, y) for x in ["충무식당", "전주콩나물국밥집", "노브랜드 버거", "송황칼국수", "허수아비 돈까스"] for y in ["라크레모사",  "루엘드 파리",  "바나프레소", "스타벅스",  "9카페"]]
# Out:
# [('충무식당', '라크레모사'),
#  ('충무식당', '루엘드 파리'),
#  ('충무식당', '바나프레소'),
#  ('충무식당', '스타벅스'),
#  ('충무식당', '9카페'),
#  ('전주콩나물국밥집', '라크레모사'),
#  ('전주콩나물국밥집', '루엘드 파리'),
#  ('전주콩나물국밥집', '바나프레소'),
#  ('전주콩나물국밥집', '스타벅스'),
#  ('전주콩나물국밥집', '9카페'),
#  ('노브랜드 버거', '라크레모사'),
#  ('노브랜드 버거', '루엘드 파리'),
#  ('노브랜드 버거', '바나프레소'),
#  ('노브랜드 버거', '스타벅스'),
#  ('노브랜드 버거', '9카페'),
#  ('송황칼국수', '라크레모사'),
#  ('송황칼국수', '루엘드 파리'),
#  ('송황칼국수', '바나프레소'),
#  ('송황칼국수', '스타벅스'),
#  ('송황칼국수', '9카페'),
#  ('허수아비 돈까스', '라크레모사'),
#  ('허수아비 돈까스', '루엘드 파리'),
#  ('허수아비 돈까스', '바나프레소'),
#  ('허수아비 돈까스', '스타벅스'),
#  ('허수아비 돈까스', '9카페')]

# %%
import random

food_type = input("오늘 뭐 먹을까? 한식, 중식, 일식, 양식, 분식, 패스트푸드, 기타")
desert_choice = input("디저트도 먹을래? 좋아 or 싫어")

korean_food = ["충무식당", "전주콩나물국밥집", "신촌설렁탕",  "북창동순두부", "깐부점심뷔페", "왕산골명가", "강찬구진순대", "장꼬방묵은김치찌개"]
chinese_food = ["매화"]
japanese_food = ["스시환", "스시 36.5"]
western_food = ["허수아비돈까스", "금화왕돈까스"]
school_food = ["단풍애김밥", "국대떡볶이", "한솥도시락"]
fast_food = ["노브랜드버거", "롯데리아"]
etc = ["레몬그라스 타이"]
desert = ["라크레모사",  "루엘드 파리",  "바나프레소", "스타벅스",  "9카페"]

if food_type == "한식":
    pick_korean = random.choice(korean_food)
    print(pick_korean)
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(pick_desert)
elif food_type == "중식":
    pick_chinese = random.choice(chinese_food)
    print(pick_chinese)
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(pick_desert)
elif food_type == "일식":
    pick_japanese = random.choice(japanese_food)
    print(pick_japanese)
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(pick_desert)
elif food_type == "양식":
    pick_western = random.choice(western_food)
    print(pick_western)
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(pick_desert)
elif food_type == "분식":
    pick_school = random.choice(school_food)
    print(pick_school)
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(pick_desert)
elif food_type == "패스트푸드":
    pick_fast = random.choice(fast_food)
    print(pick_fast)
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(pick_desert)
elif food_type == "기타":
    pick_etc = random.choice(etc)
    print(pick_etc)
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(pick_desert)
else:
    print("제대로 입력해주세요")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-01d3009a2e05> in <module>
#       1 import random
#       2
# ----> 3 food_type = input("오늘 뭐 먹을까? 한식, 중식, 일식, 양식, 분식, 패스트푸드, 기타")
#       4 desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
#       5
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
import random

# food_type = input("오늘 뭐 먹을까? 한식, 중식, 일식, 양식, 분식, 패스트푸드, 기타")
# desert_choice = input("디저트도 먹을래? 좋아 or 싫어")

korean_food = ["충무식당", "전주콩나물국밥집", "신촌설렁탕",  "북창동순두부", "깐부점심뷔페", "왕산골명가", "강찬구진순대", "장꼬방묵은김치찌개"]
chinese_food = ["매화"]
japanese_food = ["스시환", "스시 36.5"]
western_food = ["허수아비돈까스", "금화왕돈까스"]
school_food = ["단풍애김밥", "국대떡볶이", "한솥도시락"]
fast_food = ["노브랜드버거", "롯데리아"]
etc = ["레몬그라스 타이"]
desert = ["라크레모사",  "루엘드 파리",  "바나프레소", "스타벅스",  "9카페"]


a = []
for x in korean_food:
    a.append(0)
print(a)
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]

# %%
# <(random 없이 숫자로 하는법)> ->  (이미, 리스트컴프리헨션은 하셧으니 while 구문 공부용..? - break, continue 활용한 예외처리목적)
korean = ['왕산골명가','충무식당','전주콩나물국밥집','신촌설렁탕','북창동순두부']
chinese = ['중국성','희래등','칭하이','매화']
japanese = ['스시환','미나미','그림나베','금화왕돈까스','허수아비돈까스']
flour = ['단풍애김밥','국대떡볶이','소소떡볶이','왕떡볶이','울엄마김밥']
dessert = ['스타벅스','바나프레소','파리바게트','이디야커피']

while True:
    ref = input("당신은 어떤 식사를 드시겠습니까?(한식, 중식, 일식, 분식)")
    if ref == "한식":
        num = input("가능한 메뉴의 수는 "+str(len(korean))+"개 입니다. 1~"+str(len(korean))+"까지의 숫자중 하나의 숫자를 골라주세요")
        print("귀하의 메뉴는"+str(korean[int(num)-1])+"입니다.")
        break
    elif ref == "중식":
        num = input("가능한 메뉴의 수는 "+str(len(chinese))+"개 입니다. 1~"+str(len(chinese))+"까지의 숫자중 하나의 숫자를 골라주세요")
        print("귀하의 메뉴는"+str(chinese[int(num)-1])+"입니다.")
        break
    elif ref == "일식":
        num = input("가능한 메뉴의 수는 "+str(len(japanese))+"개 입니다. 1~"+str(len(japanese))+"까지의 숫자중 하나의 숫자를 골라주세요")
        print("귀하의 메뉴는"+str(chinese[int(num)-1])+"입니다.")
        break
    elif ref == "분식":
        num = input("가능한 메뉴의 수는 "+str(len(flour))+"개 입니다. 1~"+str(len(flour))+"까지의 숫자중 하나의 숫자를 골라주세요")
        print("귀하의 메뉴는"+str(flour[int(num)-1])+"입니다.")
        break
    else:
        print("틀렸습니다. 다시 입력해주시기 바랍니다.")
        continue
while True:
    des = input("디저트를 드시겠습니까?(Y/N)")
    if des == 'Y':
        num = input("가능한 메뉴의 수는 "+str(len(dessert))+"개 입니다. 1~"+str(len(dessert))+"까지의 숫자중 하나의 숫자를 골라주세요")
        print("귀하의 메뉴는 "+dessert[int(num)-1]+"입니다.")
        break
    elif des == 'N':
        print("열공하세요")
        break
    else:
        print("틀렸습니다. 다시 입력해주시기 바랍니다.")
        continue
# Out:
# 당신은 어떤 식사를 드시겠습니까?(한식, 중식, 일식, 분식)한식
# 가능한 메뉴의 수는 5개 입니다. 1~5까지의 숫자중 하나의 숫자를 골라주세요2
# 귀하의 메뉴는충무식당입니다.
# 디저트를 드시겠습니까?(Y/N)y
# 틀렸습니다. 다시 입력해주시기 바랍니다.
# 디저트를 드시겠습니까?(Y/N)Y
# 가능한 메뉴의 수는 4개 입니다. 1~4까지의 숫자중 하나의 숫자를 골라주세요2
# 귀하의 메뉴는 바나프레소입니다.

# %%
korean = ['왕산골명가','충무식당','전주콩나물국밥집','신촌설렁탕','북창동순두부']
chinese = ['중국성','희래등','칭하이','매화']
japanese = ['스시환','미나미','그림나베','금화왕돈까스','허수아비돈까스']
flour = ['단풍애김밥','국대떡볶이','소소떡볶이','왕떡볶이','울엄마김밥']
dessert = ['스타벅스','바나프레소','파리바게트','이디야커피']

ref = input("당신은 어떤 식사를 드시겠습니까?(한식, 중식, 일식, 분식)")
if ref == "한식":
    num = input("가능한 메뉴의 수는 "+str(len(korean))+"개 입니다. 1~"+str(len(korean))+"까지의 숫자중 하나의 숫자를 골라주세요")
    print("귀하의 메뉴는"+str(korean[int(num)-1])+"입니다.")
elif ref == "중식":
    num = input("가능한 메뉴의 수는 "+str(len(chinese))+"개 입니다. 1~"+str(len(chinese))+"까지의 숫자중 하나의 숫자를 골라주세요")
    print("귀하의 메뉴는"+str(chinese[int(num)-1])+"입니다.")
elif ref == "일식":
    num = input("가능한 메뉴의 수는 "+str(len(japanese))+"개 입니다. 1~"+str(len(japanese))+"까지의 숫자중 하나의 숫자를 골라주세요")
    print("귀하의 메뉴는"+str(chinese[int(num)-1])+"입니다.")
elif ref == "분식":
    num = input("가능한 메뉴의 수는 "+str(len(flour))+"개 입니다. 1~"+str(len(flour))+"까지의 숫자중 하나의 숫자를 골라주세요")
    print("귀하의 메뉴는"+str(flour[int(num)-1])+"입니다.")
else:
    print("틀렸습니다. 다시 입력해주시기 바랍니다.")
# Out:
# 당신은 어떤 식사를 드시겠습니까?(한식, 중식, 일식, 분식)한식
# 가능한 메뉴의 수는 5개 입니다. 1~5까지의 숫자중 하나의 숫자를 골라주세요1
# 귀하의 메뉴는왕산골명가입니다.

# %%
import random

food_type = input("오늘 뭐 먹을까? 한식, 중식, 일식, 양식, 분식, 패스트푸드, 기타")
# desert_choice = input("디저트도 먹을래? 좋아 or 싫어")

korean_food = ["충무식당", "전주콩나물국밥집", "신촌설렁탕",  "북창동순두부", "깐부점심뷔페", "왕산골명가", "강찬구진순대", "장꼬방묵은김치찌개"]
chinese_food = ["매화"]
japanese_food = ["스시환", "스시 36.5"]
western_food = ["허수아비돈까스", "금화왕돈까스"]
school_food = ["단풍애김밥", "국대떡볶이", "한솥도시락"]
fast_food = ["노브랜드버거", "롯데리아"]
etc = ["레몬그라스 타이"]
desert = ["라크레모사",  "루엘드 파리",  "바나프레소", "스타벅스",  "9카페"]

if food_type == "한식":
    pick_korean = random.choice(korean_food)
    print(f"오늘의 식당은 {pick_korean}!")
    desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(f"오늘의 카페는 {pick_desert}!")
    else:
        print("그래! 남은 시간은 공부하자!")
elif food_type == "중식":
    pick_chinese = random.choice(chinese_food)
    print(f"오늘의 식당은 {pick_chinese}!")
    desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(f"오늘의 카페는 {pick_desert}!")
    else:
        print("그래! 남은 시간은 공부하자!")
elif food_type == "일식":
    pick_japanese = random.choice(japanese_food)
    print(f"오늘의 식당은 {pick_japanese}!")
    desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(f"오늘의 카페는 {pick_desert}!")
    else:
        print("그래! 남은 시간은 공부하자!")
elif food_type == "양식":
    pick_western = random.choice(western_food)
    print(f"오늘의 식당은 {pick_western}!")
    desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(f"오늘의 카페는 {pick_desert}!")
    else:
        print("그래! 남은 시간은 공부하자!")
elif food_type == "분식":
    pick_school = random.choice(school_food)
    print(f"오늘의 식당은 {pick_school}!")
    desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(f"오늘의 카페는 {pick_desert}!")
    else:
        print("그래! 남은 시간은 공부하자!")
elif food_type == "패스트푸드":
    pick_fast = random.choice(fast_food)
    print(f"오늘의 식당은 {pick_fast}!")
    desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(f"오늘의 카페는 {pick_desert}!")
    else:
        print("그래! 남은 시간은 공부하자!")
elif food_type == "기타":
    pick_etc = random.choice(etc)
    print(f"오늘의 식당은 {pick_etc}!")
    desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
    if desert_choice == "좋아":
        pick_desert = random.choice(desert)
        print(f"오늘의 카페는 {pick_desert}!")
    else:
        print("그래! 남은 시간은 공부하자!")
else:
    print("제대로 입력해주세요")
# Out:
# 오늘 뭐 먹을까? 한식, 중식, 일식, 양식, 분식, 패스트푸드, 기타중식
# 오늘의 식당은 매화!
# 디저트도 먹을래? 좋아 or 싫어좋아
# 오늘의 카페는 루엘드 파리!

# %%
import random

food_type = input("오늘 뭐 먹을까? 한식, 중식, 일식, 양식, 분식, 패스트푸드, 기타")
# desert_choice = input("디저트도 먹을래? 좋아 or 싫어")

k_food = ["충무식당", "전주콩나물국밥집", "신촌설렁탕",  "북창동순두부", "깐부점심뷔페", "왕산골명가", "강찬구진순대", "장꼬방묵은김치찌개"]
c_food = ["매화"]
j_food = ["스시환", "스시 36.5"]
w_food = ["허수아비돈까스", "금화왕돈까스"]
s_food = ["단풍애김밥", "국대떡볶이", "한솥도시락"]
f_food = ["노브랜드버거", "롯데리아"]
etc = ["레몬그라스 타이"]
desert = ["라크레모사",  "루엘드 파리",  "바나프레소", "스타벅스",  "9카페"]

while True:
    if food_type == "한식":
        pick_k = random.choice(k_food)
        print(f"오늘의 식당은 {pick_k}!")
        isGood = input("여기 갈까? 좋아 or 싫어")
        if isGood == "좋아":
            desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
            if desert_choice == "좋아":
                pick_desert = random.choice(desert)
                print(f"오늘의 카페는 {pick_desert}!")
            else:
                print("그래! 남은 시간은 공부하자!")
            break
        else:
            continue

    elif food_type == "중식":
        pick_c = random.choice(c_food)
        print(f"오늘의 식당은 {pick_c}!")
        isGood = input("여기 갈까? 좋아 or 싫어")
        if isGood == "좋아":
            desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
            if desert_choice == "좋아":
                pick_desert = random.choice(desert)
                print(f"오늘의 카페는 {pick_desert}!")
            else:
                print("그래! 남은 시간은 공부하자!")
            break
        else:
            continue
            
    elif food_type == "일식":
        pick_j = random.choice(j_food)
        print(f"오늘의 식당은 {pick_j}!")
        isGood = input("여기 갈까? 좋아 or 싫어")
        if isGood == "좋아":
            desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
            if desert_choice == "좋아":
                pick_desert = random.choice(desert)
                print(f"오늘의 카페는 {pick_desert}!")
            else:
                print("그래! 남은 시간은 공부하자!")
            break
        else:
            continue
            
    elif food_type == "양식":
        pick_w = random.choice(w_food)
        print(f"오늘의 식당은 {pick_w}!")
        isGood = input("여기 갈까? 좋아 or 싫어")
        if isGood == "좋아":
            desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
            if desert_choice == "좋아":
                pick_desert = random.choice(desert)
                print(f"오늘의 카페는 {pick_desert}!")
            else:
                print("그래! 남은 시간은 공부하자!")
            break
        else:
            continue
            
    elif food_type == "분식":
        pick_s = random.choice(s_food)
        print(f"오늘의 식당은 {pick_s}!")
        isGood = input("여기 갈까? 좋아 or 싫어")
        if isGood == "좋아":
            desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
            if desert_choice == "좋아":
                pick_desert = random.choice(desert)
                print(f"오늘의 카페는 {pick_desert}!")
            else:
                print("그래! 남은 시간은 공부하자!")
            break
        else:
            continue
            
    elif food_type == "패스트푸드":
        pick_f = random.choice(f_food)
        print(f"오늘의 식당은 {pick_f}!")
        isGood = input("여기 갈까? 좋아 or 싫어")
        if isGood == "좋아":
            desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
            if desert_choice == "좋아":
                pick_desert = random.choice(desert)
                print(f"오늘의 카페는 {pick_desert}!")
            else:
                print("그래! 남은 시간은 공부하자!")
            break
        else:
            continue
            
    elif food_type == "기타":
        pick_e = random.choice(etc)
        print(f"오늘의 식당은 {pick_e}!")
        isGood = input("여기 갈까? 좋아 or 싫어")
        if isGood == "좋아":
            desert_choice = input("디저트도 먹을래? 좋아 or 싫어")
            if desert_choice == "좋아":
                pick_desert = random.choice(desert)
                print(f"오늘의 카페는 {pick_desert}!")
            else:
                print("그래! 남은 시간은 공부하자!")
            break
        else:
            continue
            
    else:
        print("다시 입력해주세요")
# Out:
# 오늘 뭐 먹을까? 한식, 중식, 일식, 양식, 분식, 패스트푸드, 기타분식
# 오늘의 식당은 국대떡볶이!
# 여기 갈까? 좋아 or 싫어싫어
# 오늘의 식당은 한솥도시락!
# 여기 갈까? 좋아 or 싫어싫어
# 오늘의 식당은 단풍애김밥!
# 여기 갈까? 좋아 or 싫어싫어
# 오늘의 식당은 한솥도시락!
# 여기 갈까? 좋아 or 싫어좋아
# 디저트도 먹을래? 좋아 or 싫어싫어
# 그래! 남은 시간은 공부하자!
