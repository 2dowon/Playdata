# %%
import pandas as pd 

bicycle_data = pd.read_csv("./data/test.csv", encoding = "cp949")
bicycle_data
# Out:
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              자전거번호                 대여일시  대여 대여소번호               대여 대여소명 대여거치대  \
# 0        SPB-31707  2020-04-30 23:23:31       113          홍대입구역 2번출구 앞     0
# 1        SPB-13960  2020-04-30 23:36:34      1835               STX V타워     8
# 2        SPB-23175  2020-04-30 23:34:28      2025              흑석역 1번출구     2
# 3        SPB-30615  2020-04-30 23:52:00       457            종로꽃시장 입구 옆     0
# 4        SPB-30150  2020-04-30 23:23:27       113          홍대입구역 2번출구 앞     0
# ...            ...                  ...       ...                   ...   ...
# 2197470  SPB-33341  2020-05-31 21:55:55      1363               보문4교 인근     0
# 2197471  SPB-21898  2020-05-31 03:15:54      1149             신방화역환승주차장     7
# ...
